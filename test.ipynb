# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("evil larry")
# Out:
# evil larry

# %%
print("67")
# Out:
# 67

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
